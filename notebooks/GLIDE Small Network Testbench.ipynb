# %%
import sys
sys.path.append("../")

# %%
import importlib
import denoise.algorithms.dsd.denoise as glide
import denoise.algorithms.dsd.computations as dsd
import denoise.graph.io as graph_io
import denoise.algorithms.dsd.denoise_updated as d_up
import time

# %%
params       =  {
    "loc"   : "l3",
    "alpha" : 2.0,
    "beta"  : 100,
    "delta" : 0.01,
}

# %%
edgelist, node_list, node_map = graph_io.parse_graph_file("../data/test_graphs/All_Graphs/Graph1.txt")
X                             = dsd.compute_embedding(edgelist)

# %%
tic = time.perf_counter()
updated_edgelist              = d_up.glide_predict_links(edgelist, X, params = params)[0 : 100]
print(time.perf_counter() - tic)
# Out:
# 2033.4539203110007

# %%
updated_edgelist
# Out:
# [(121, 65, 269.87030618220984),
#  (147, 65, 255.25311819511143),
#  (147, 121, 255.25311819511143),
#  (216, 121, 243.48228945639733),
#  (216, 65, 243.4822894563973),
#  (199, 65, 243.2782387920345),
#  (199, 121, 243.2782387920345),
#  (189, 65, 242.9655292125526),
#  (189, 121, 242.96552921255258),
#  (65, 63, 242.54952687072938),
#  (121, 63, 242.54952687072927),
#  (158, 65, 239.83293247770956),
#  (158, 121, 239.83293247770956),
#  (65, 28, 239.09499134194243),
#  (121, 28, 239.09499134194235),
#  (228, 65, 237.43486618354447),
#  (228, 121, 237.43486618354447),
#  (216, 147, 228.68519337757215),
#  (199, 147, 228.36707687261205),
#  (154, 65, 225.8272423357738),
#  (154, 121, 225.82724233577378),
#  (279, 65, 225.6354285467883),
#  (279, 121, 225.6354285467883),
#  (71, 65, 225.2359131978099),
#  (121, 71, 225.235913197809),
#  (147, 63, 225.01532156726552),
#  (201, 65, 224.3412317494922),
#  (201, 121, 224.3412317494922),
#  (189, 147, 220.77774439015633),
# ...

# %%
params       =  {
    "loc"           : "l3",
    "alpha"         : 2.0,
    "beta"          : 100,
    "delta"         : 0.01,
    "so_location"   : "/home/kapil/Documents/GraphTrim/Trimming_Functional/denoise/algorithms/dsd/libl3.so",
    "ctypes_on"     : True
}

# %%
tic = time.perf_counter()
updated_edgelist_ctype           = d_up.glide_predict_links(edgelist, X, params = params)[0 : 100]
print(time.perf_counter() - tic)
# Out:
# 11.243390888000249

# %%
updated_edgelist_ctype
# Out:
# [(121, 65, 269.87030618220984),
#  (147, 65, 255.25311819511143),
#  (147, 121, 255.25311819511143),
#  (216, 121, 243.48228945639733),
#  (216, 65, 243.4822894563973),
#  (199, 65, 243.2782387920345),
#  (199, 121, 243.2782387920345),
#  (189, 65, 242.9655292125526),
#  (189, 121, 242.96552921255258),
#  (65, 63, 242.54952687072938),
#  (121, 63, 242.54952687072927),
#  (158, 65, 239.83293247770956),
#  (158, 121, 239.83293247770956),
#  (65, 28, 239.09499134194243),
#  (121, 28, 239.09499134194235),
#  (228, 65, 237.43486618354447),
#  (228, 121, 237.43486618354447),
#  (216, 147, 228.68519337757215),
#  (199, 147, 228.36707687261205),
#  (154, 65, 225.8272423357738),
#  (154, 121, 225.82724233577378),
#  (279, 65, 225.6354285467883),
#  (279, 121, 225.6354285467883),
#  (71, 65, 225.2359131978099),
#  (121, 71, 225.235913197809),
#  (147, 63, 225.01532156726552),
#  (201, 65, 224.3412317494922),
#  (201, 121, 224.3412317494922),
#  (189, 147, 220.77774439015633),
# ...
